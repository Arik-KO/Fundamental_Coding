# %%
import torch
torch.__version__
# Out:
# '2.9.1+cu126'

# %% [markdown]
# # Playing with Unsqueeze Function

# %%
var_x = torch.rand(3)

# %% [markdown]
# var_x.shape

# %%
var_y = var_x.unsqueeze(0)

# %%
var_y.shape
# Out:
# torch.Size([1, 3])

# %%
var_y
# Out:
# tensor([[0.0623, 0.4807, 0.9880]])

# %%
var_x
# Out:
# tensor([0.0623, 0.4807, 0.9880])

# %%
var_z = var_x.unsqueeze(1)

# %%
var_z
# Out:
# tensor([[0.0623],
#         [0.4807],
#         [0.9880]])

# %%
var_z.shape
# Out:
# torch.Size([3, 1])

# %% [markdown]
# # Use of seeds for reproduceability

# %%
torch.manual_seed(42)

# %%
x = torch.rand(3)
print(x)
print(f"shape of the random array is {x.shape}")
# Out:
# tensor([0.8823, 0.9150, 0.3829])
# shape of the random array is torch.Size([3])
